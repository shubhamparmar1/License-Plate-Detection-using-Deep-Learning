# %%
# !cd yolov5 && pip install -r requirements.txt
# Out:
# Collecting gitpython>=3.1.30 (from -r requirements.txt (line 5))
#   Obtaining dependency information for gitpython>=3.1.30 from https://files.pythonhosted.org/packages/8d/c4/82b858fb6483dfb5e338123c154d19c043305b01726a67d89532b8f8f01b/GitPython-3.1.40-py3-none-any.whl.metadata
#   Downloading GitPython-3.1.40-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: matplotlib>=3.3 in c:\users\deval\appdata\local\programs\python\python311\lib\site-packages (from -r requirements.txt (line 6)) (3.7.2)
# Requirement already satisfied: numpy>=1.22.2 in c:\users\deval\appdata\local\programs\python\python311\lib\site-packages (from -r requirements.txt (line 7)) (1.25.2)
# Requirement already satisfied: opencv-python>=4.1.1 in c:\users\deval\appdata\local\programs\python\python311\lib\site-packages (from -r requirements.txt (line 8)) (4.8.0.76)
# Requirement already satisfied: Pillow>=7.1.2 in c:\users\deval\appdata\local\programs\python\python311\lib\site-packages (from -r requirements.txt (line 9)) (9.5.0)
# Requirement already satisfied: psutil in c:\users\deval\appdata\local\programs\python\python311\lib\site-packages (from -r requirements.txt (line 10)) (5.9.5)
# Requirement already satisfied: PyYAML>=5.3.1 in c:\users\deval\appdata\local\programs\python\python311\lib\site-packages (from -r requirements.txt (line 11)) (6.0.1)
# Requirement already satisfied: requests>=2.23.0 in c:\users\deval\appdata\local\programs\python\python311\lib\site-packages (from -r requirements.txt (line 12)) (2.31.0)
# Requirement already satisfied: scipy>=1.4.1 in c:\users\deval\appdata\local\programs\python\python311\lib\site-packages (from -r requirements.txt (line 13)) (1.11.2)
# Collecting thop>=0.1.1 (from -r requirements.txt (line 14))
#   Downloading thop-0.1.1.post2209072238-py3-none-any.whl (15 kB)
# Requirement already satisfied: torch>=1.8.0 in c:\users\deval\appdata\local\programs\python\python311\lib\site-packages (from -r requirements.txt (line 15)) (2.0.1)
# Requirement already satisfied: torchvision>=0.9.0 in c:\users\deval\appdata\local\programs\python\python311\lib\site-packages (from -r requirements.txt (line 16)) (0.15.2)
# Requirement already satisfied: tqdm>=4.64.0 in c:\users\deval\appdata\local\programs\python\python311\lib\site-packages (from -r requirements.txt (line 17)) (4.66.1)
# Requirement already satisfied: ultralytics>=8.0.147 in c:\users\deval\appdata\local\programs\python\python311\lib\site-packages (from -r requirements.txt (line 18)) (8.0.163)
# Requirement already satisfied: pandas>=1.1.4 in c:\users\deval\appdata\local\programs\python\python311\lib\site-packages (from -r requirements.txt (line 27)) (2.0.3)
# Requirement already satisfied: seaborn>=0.11.0 in c:\users\deval\appdata\local\programs\python\python311\lib\site-packages (from -r requirements.txt (line 28)) (0.12.2)
# Collecting setuptools>=65.5.1 (from -r requirements.txt (line 42))
#   Obtaining dependency information for setuptools>=65.5.1 from https://files.pythonhosted.org/packages/bb/26/7945080113158354380a12ce26873dd6c1ebd88d47f5bc24e2c5bb38c16a/setuptools-68.2.2-py3-none-any.whl.metadata
#   Downloading setuptools-68.2.2-py3-none-any.whl.metadata (6.3 kB)
# Collecting gitdb<5,>=4.0.1 (from gitpython>=3.1.30->-r requirements.txt (line 5))
#   Obtaining dependency information for gitdb<5,>=4.0.1 from https://files.pythonhosted.org/packages/fd/5b/8f0c4a5bb9fd491c277c21eff7ccae71b47d43c4446c9d0c6cff2fe8c2c4/gitdb-4.0.11-py3-none-any.whl.metadata
#   Downloading gitdb-4.0.11-py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\deval\appdata\local\programs\python\python311\lib\site-packages (from matplotlib>=3.3->-r requirements.txt (line 6)) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\deval\appdata\local\programs\python\python311\lib\site-packages (from matplotlib>=3.3->-r requirements.txt (line 6)) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\deval\appdata\local\programs\python\python311\lib\site-packages (from matplotlib>=3.3->-r requirements.txt (line 6)) (4.42.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\deval\appdata\local\programs\python\python311\lib\site-packages (from matplotlib>=3.3->-r requirements.txt (line 6)) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\deval\appdata\local\programs\python\python311\lib\site-packages (from matplotlib>=3.3->-r requirements.txt (line 6)) (23.1)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in c:\users\deval\appdata\local\programs\python\python311\lib\site-packages (from matplotlib>=3.3->-r requirements.txt (line 6)) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\deval\appdata\local\programs\python\python311\lib\site-packages (from matplotlib>=3.3->-r requirements.txt (line 6)) (2.8.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\deval\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.23.0->-r requirements.txt (line 12)) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\deval\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.23.0->-r requirements.txt (line 12)) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\deval\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.23.0->-r requirements.txt (line 12)) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\deval\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.23.0->-r requirements.txt (line 12)) (2023.7.22)
# Requirement already satisfied: filelock in c:\users\deval\appdata\local\programs\python\python311\lib\site-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (3.12.2)
# Requirement already satisfied: typing-extensions in c:\users\deval\appdata\local\programs\python\python311\lib\site-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (4.7.1)
# Requirement already satisfied: sympy in c:\users\deval\appdata\local\programs\python\python311\lib\site-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (1.12)
# Requirement already satisfied: networkx in c:\users\deval\appdata\local\programs\python\python311\lib\site-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (3.1)
# Requirement already satisfied: jinja2 in c:\users\deval\appdata\local\programs\python\python311\lib\site-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (3.1.2)
# Requirement already satisfied: colorama in c:\users\deval\appdata\local\programs\python\python311\lib\site-packages (from tqdm>=4.64.0->-r requirements.txt (line 17)) (0.4.6)
# Requirement already satisfied: py-cpuinfo in c:\users\deval\appdata\local\programs\python\python311\lib\site-packages (from ultralytics>=8.0.147->-r requirements.txt (line 18)) (9.0.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\deval\appdata\local\programs\python\python311\lib\site-packages (from pandas>=1.1.4->-r requirements.txt (line 27)) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\deval\appdata\local\programs\python\python311\lib\site-packages (from pandas>=1.1.4->-r requirements.txt (line 27)) (2023.3)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->gitpython>=3.1.30->-r requirements.txt (line 5))
#   Obtaining dependency information for smmap<6,>=3.0.1 from https://files.pythonhosted.org/packages/a7/a5/10f97f73544edcdef54409f1d839f6049a0d79df68adbc1ceb24d1aaca42/smmap-5.0.1-py3-none-any.whl.metadata
#   Downloading smmap-5.0.1-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: six>=1.5 in c:\users\deval\appdata\local\programs\python\python311\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.3->-r requirements.txt (line 6)) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\deval\appdata\local\programs\python\python311\lib\site-packages (from jinja2->torch>=1.8.0->-r requirements.txt (line 15)) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in c:\users\deval\appdata\local\programs\python\python311\lib\site-packages (from sympy->torch>=1.8.0->-r requirements.txt (line 15)) (1.3.0)
# Downloading GitPython-3.1.40-py3-none-any.whl (190 kB)
#    ---------------------------------------- 0.0/190.6 kB ? eta -:--:--
#    --------------------------------------- 190.6/190.6 kB 11.3 MB/s eta 0:00:00
# Downloading setuptools-68.2.2-py3-none-any.whl (807 kB)
#    ---------------------------------------- 0.0/807.9 kB ? eta -:--:--
#    --------------------- ----------------- 450.6/807.9 kB 14.2 MB/s eta 0:00:01
#    --------------------------------------- 807.9/807.9 kB 12.9 MB/s eta 0:00:00
# Downloading gitdb-4.0.11-py3-none-any.whl (62 kB)
#    ---------------------------------------- 0.0/62.7 kB ? eta -:--:--
#    ---------------------------------------- 62.7/62.7 kB 3.5 MB/s eta 0:00:00
# Downloading smmap-5.0.1-py3-none-any.whl (24 kB)
# Installing collected packages: smmap, setuptools, gitdb, thop, gitpython
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 65.5.0
#     Uninstalling setuptools-65.5.0:
#       Successfully uninstalled setuptools-65.5.0
# Successfully installed gitdb-4.0.11 gitpython-3.1.40 setuptools-68.2.2 smmap-5.0.1 thop-0.1.1.post2209072238
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import torch
from matplotlib import pyplot as plt
import numpy as np
import cv2

# %%
model = torch.hub.load('yolov5', 'custom', path='best.pt', source='local', force_reload=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# d:\B.Tech_7_sem\Final_Year_Project\Code\my\project\content\n1.ipynb Cell 3 line 1
# ----> <a href='vscode-notebook-cell:/d%3A/B.Tech_7_sem/Final_Year_Project/Code/my/project/content/n1.ipynb#W2sZmlsZQ%3D%3D?line=0'>1</a> model = torch.hub.load('yolov5', 'custom', path='best.pt', source='local', force_reload=True)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch\hub.py:566, in load(repo_or_dir, model, source, trust_repo, force_reload, verbose, skip_validation, *args, **kwargs)
#     562 if source == 'github':
#     563     repo_or_dir = _get_cache_or_reload(repo_or_dir, force_reload, trust_repo, "load",
#     564                                        verbose=verbose, skip_validation=skip_validation)
# --> 566 model = _load_local(repo_or_dir, model, *args, **kwargs)
#     567 return model
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch\hub.py:595, in _load_local(hubconf_dir, model, *args, **kwargs)
#     592     hub_module = _import_module(MODULE_HUBCONF, hubconf_path)
#     594     entry = _load_entry_from_hubconf(hub_module, model)
# --> 595     model = entry(*args, **kwargs)
#     597 return model
#
# File d:\B.Tech_7_sem\Final_Year_Project\Code\my\project\content\yolov5\hubconf.py:83, in custom(path, autoshape, _verbose, device)
#      81 def custom(path='path/to/model.pt', autoshape=True, _verbose=True, device=None):
#      82     # YOLOv5 custom or local model
# ---> 83     return _create(path, autoshape=autoshape, verbose=_verbose, device=device)
#
# File d:\B.Tech_7_sem\Final_Year_Project\Code\my\project\content\yolov5\hubconf.py:33, in _create(name, pretrained, channels, classes, autoshape, verbose, device)
#      17 """Creates or loads a YOLOv5 model
#      18
#      19 Arguments:
#    (...)
#      29     YOLOv5 model
#      30 """
#      31 from pathlib import Path
# ---> 33 from models.common import AutoShape, DetectMultiBackend
#      34 from models.experimental import attempt_load
#      35 from models.yolo import ClassificationModel, DetectionModel, SegmentationModel
#
# File ~/.cache\torch\hub\ultralytics_yolov5_master\models\common.py:29
#      27 # Import 'ultralytics' package or install if if missing
#      28 try:
# ---> 29     import ultralytics
#      31     assert hasattr(ultralytics, '__version__')  # verify package is not directory
#      32 except (ImportError, AssertionError):
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\ultralytics\__init__.py:5
#       1 # Ultralytics YOLO 🚀, AGPL-3.0 license
#       3 __version__ = '8.0.212'
# ----> 5 from ultralytics.models import RTDETR, SAM, YOLO
#       6 from ultralytics.models.fastsam import FastSAM
#       7 from ultralytics.models.nas import NAS
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\ultralytics\models\__init__.py:3
#       1 # Ultralytics YOLO 🚀, AGPL-3.0 license
# ----> 3 from .rtdetr import RTDETR
#       4 from .sam import SAM
#       5 from .yolo import YOLO
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\ultralytics\models\rtdetr\__init__.py:3
#       1 # Ultralytics YOLO 🚀, AGPL-3.0 license
# ----> 3 from .model import RTDETR
#       4 from .predict import RTDETRPredictor
#       5 from .val import RTDETRValidator
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\ultralytics\models\rtdetr\model.py:10
#       1 # Ultralytics YOLO 🚀, AGPL-3.0 license
#       2 """
#       3 Interface for Baidu's RT-DETR, a Vision Transformer-based real-time object detector. RT-DETR offers real-time
#       4 performance and high accuracy, excelling in accelerated backends like CUDA with TensorRT. It features an efficient
#    (...)
#       7 For more information on RT-DETR, visit: https://arxiv.org/pdf/2304.08069.pdf
#       8 """
# ---> 10 from ultralytics.engine.model import Model
#      11 from ultralytics.nn.tasks import RTDETRDetectionModel
#      13 from .predict import RTDETRPredictor
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\ultralytics\engine\model.py:8
#       5 from pathlib import Path
#       6 from typing import Union
# ----> 8 from ultralytics.cfg import TASK2DATA, get_cfg, get_save_dir
#       9 from ultralytics.hub.utils import HUB_WEB_ROOT
#      10 from ultralytics.nn.tasks import attempt_load_one_weight, guess_model_task, nn, yaml_model_load
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\ultralytics\cfg\__init__.py:10
#       7 from types import SimpleNamespace
#       8 from typing import Dict, List, Union
# ---> 10 from ultralytics.utils import (ASSETS, DEFAULT_CFG, DEFAULT_CFG_DICT, DEFAULT_CFG_PATH, LOGGER, RANK, ROOT, RUNS_DIR,
#      11                                SETTINGS, SETTINGS_YAML, TESTS_RUNNING, IterableSimpleNamespace, __version__, checks,
#      12                                colorstr, deprecation_warn, yaml_load, yaml_print)
#      14 # Define valid tasks and modes
#      15 MODES = 'train', 'val', 'predict', 'export', 'track', 'benchmark'
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\ultralytics\utils\__init__.py:248
#     244     return logger
#     247 # Set logger
# --> 248 LOGGER = set_logging(LOGGING_NAME, verbose=VERBOSE)  # define globally (used in train.py, val.py, predict.py, etc.)
#     249 for logger in 'sentry_sdk', 'urllib3.connectionpool':
#     250     logging.getLogger(logger).setLevel(logging.CRITICAL)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\ultralytics\utils\__init__.py:233, in set_logging(name, verbose)
#     231 # Configure the console (stdout) encoding to UTF-8
#     232 if WINDOWS:  # for Windows
# --> 233     sys.stdout.reconfigure(encoding='utf-8')
#     235 # Create and configure the StreamHandler
#     236 stream_handler = logging.StreamHandler(sys.stdout)
#
# AttributeError: 'OutStream' object has no attribute 'reconfigure'

# %%
img = 'tru.png'

# %%
result = model(img)

# %%
# %matplotlib inline 
plt.imshow(np.squeeze(result.render()))
plt.show()

# %%
import cv2
import numpy as np
import easyocr

cap = cv2.VideoCapture('sample.mp4')

# Define the desired width and height for the display window
desired_width = 1080
desired_height = 720

# Define the frame skip value
frame_skip = 10  # process every 10th frame

frame_counter = 0

# Initialize EasyOCR reader
reader = easyocr.Reader(['en'])

# Define the confidence threshold
confidence_threshold = 0.3

while cap.isOpened():
    ret, frame = cap.read()
    
    if ret:
        frame_counter += 1
        if frame_counter % frame_skip == 0:  # only process every nth frame
            # Resize the frame to the desired width and height
            resized_frame = cv2.resize(frame, (desired_width, desired_height))
            
            # Make detections 
            yolo_results = model(resized_frame)
            
            # Extract bounding boxes from the results
            boxes = yolo_results.xyxy[0].cpu().numpy()  # adjust this line based on your model's output
            
            for box in boxes:
                # Extract coordinates
                x1, y1, x2, y2 = box[:4].astype(int)
                
                # Extract region from the frame
                region = resized_frame[y1:y2, x1:x2]
                region  = cv2.cvtColor(region, cv2.COLOR_BGR2GRAY)
                _, region = cv2.threshold(region, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)

                # Use EasyOCR to detect text
                ocr_results = reader.readtext(region)
                
                for result in ocr_results:
                    text, confidence = result[1], result[2]
                    if confidence > confidence_threshold:
                        print(text)
            
            cv2.imshow('YOLO', np.squeeze(yolo_results.render()))
        
        if cv2.waitKey(10) & 0xFF == ord('q'):
            break
    else:
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# CIIs @GJ
# LRDTQ
# FFH
# Lybicd
# J8C65 USJ
